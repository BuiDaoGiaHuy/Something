# %% [markdown]
# <a href="https://colab.research.google.com/github/BuiDaoGiaHuy/something/blob/master/correlate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
def correlate(I,F,S=1):
  H,W=I.shape[:2]
  f=F.shape[0]
  F=F.reshape((f,f,1))
  P=int(((H-1)*S-H+f)/2)
  I_pad=np.pad(I, ((P,),(P,),(0,)),'constant', constant_values=0)
  I_res=np.zeros((H, W, 3))
  for h in range(H):
    for w in range(W):
      for i in range(f):
        for j in range(f):
          I_res[h,w]+=I_pad[h*S+i,w*S+j]*F[i][j]
  return I_res

# %%
dx=np.array([[-1,0,1],[-2,0,2],[-1,0,1]],dtype=np.float64)
dy=np.array([[-1,-2,-1],[0,0,0],[1,2,1]],dtype=np.float64)

# %%
img=cv2.imread('/content/84092146_1487935058048495_4014219431482753024_o.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x960 at 0x7FD8262BA6A0>

# %%
cv2_imshow(correlate(img,dx)+correlate(img,dy))
# Out:
# <PIL.Image.Image image mode=RGB size=768x960 at 0x7FD825A449B0>
